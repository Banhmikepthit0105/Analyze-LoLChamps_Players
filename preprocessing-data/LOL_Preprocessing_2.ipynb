# %%
import pandas as pd


player_df = pd.read_csv("./data/preprocessed_data/processed_player_stats.csv", encoding="utf-8")
player_df
# Out:
#       Year      Tournamment             Team    Player   G   W   L    WR  \
# 0     2018    Spring_Season   Cherry Esports  Artifact  34  17  17  50.0
# 1     2018    Spring_Season   Cherry Esports     Clear  34  17  17  50.0
# 2     2018    Spring_Season   Cherry Esports      Kidz  34  17  17  50.0
# 3     2018    Spring_Season   Cherry Esports      Potm  34  17  17  50.0
# 4     2018    Spring_Season   Cherry Esports     Boong  13   5   8  38.5
# ...    ...              ...              ...       ...  ..  ..  ..   ...
# 1330  2024  Summer_Playoffs  Vikings Esports       Bie  14   8   6  57.1
# 1331  2024  Summer_Playoffs  Vikings Esports      Gury  14   8   6  57.1
# 1332  2024  Summer_Playoffs  Vikings Esports      Kati  14   8   6  57.1
# 1333  2024  Summer_Playoffs  Vikings Esports    Nanaue  14   8   6  57.1
# 1334  2024  Summer_Playoffs  Vikings Esports    Shogun  14   8   6  57.1
#
#          K     D  ...                     Champs       Role  total_games  \
# 0     4.44  2.74  ...       Azir, Ryze, Vladimir  Mid Laner          134
# 1     3.62  2.29  ...   Caitlyn, Ezreal, Kog'Maw  Bot Laner          134
# 2     0.79  2.97  ...   Braum, Tahm Kench, Janna    Support          134
# 3     2.41  2.85  ...  Kha'Zix, Sejuani, Lee Sin    Jungler          134
# 4     2.38  2.85  ...         Ornn, Gnar, Rumble  Top Laner          134
# ...    ...   ...  ...                        ...        ...          ...
# 1330  1.29  3.00  ...  Rell, Renata Glasc, Senna    Support           25
# 1331  2.00  3.57  ...      Zyra, Maokai, Shyvana    Jungler           25
# 1332  4.71  2.21  ...       Zeri, Corki, Smolder  Mid Laner           25
# 1333  2.93  5.00  ...          Jax, Kennen, Gnar  Top Laner           25
# 1334  3.36  2.57  ...        Ziggs, Ezreal, Ashe  Bot Laner           25
#
#       max_G/M  max_CS/M  max_KDA  max_KPAR        Date  Season  Event_Type
# 0       464.0     10.86     7.80      76.3  2018-03-18  Spring      Season
# 1       464.0     10.86     7.80      76.3  2018-03-18  Spring      Season
# 2       464.0     10.86     7.80      76.3  2018-03-18  Spring      Season
# 3       464.0     10.86     7.80      76.3  2018-03-18  Spring      Season
# 4       464.0     10.86     7.80      76.3  2018-03-18  Spring      Season
# ...       ...       ...      ...       ...         ...     ...         ...
# 1330    491.0     10.89     9.25      78.8  2024-08-18  Summer    Playoffs
# 1331    491.0     10.89     9.25      78.8  2024-08-18  Summer    Playoffs
# 1332    491.0     10.89     9.25      78.8  2024-08-18  Summer    Playoffs
# 1333    491.0     10.89     9.25      78.8  2024-08-18  Summer    Playoffs
# 1334    491.0     10.89     9.25      78.8  2024-08-18  Summer    Playoffs
#
# [1335 rows x 30 columns]

# %%
end_dates = {
    "2018 Spring_Season": "2018-03-18",
    "2018 Spring_Playoffs": "2018-04-07",
    "2018 Summer_Promotion": "2018-05-08",
    "2018 Summer_Season": "2018-08-19",
    "2018 Summer_Playoffs": "2018-09-22",
    "2019 Spring_Promotion": "2018-11-30",
    "2019 Spring_Season": "2019-03-24",
    "2019 Spring_Playoffs": "2019-04-13",
    "2019 Summer_Promotion": "2019-04-28",
    "2019 Summer_Season": "2019-08-11",
    "2019 Summer_Playoffs": "2019-09-15",
    "2020 Spring_Promotion": "2019-12-15",
    "2020 Spring_Season": "2020-04-05",
    "2020 Spring_Playoffs": "2020-04-18",
    "2020 Summer_Promotion": "2020-05-03",
    "2020 Summer_Season": "2020-08-16",
    "2020 Summer_Playoffs": "2020-09-05",
    "2021 Spring_Promotion": "2020-11-30",
    "2021 Spring_Season": "2021-04-04",
    "2021 Spring_Playoffs": "2021-04-18",
    "2021 Summer_Promotion": "2021-05-20",
    "2021 Winter_Season": "2021-12-17",
    "2021 Winter_Playoffs": "2021-12-26",
    "2022 Spring_Season": "2022-04-13",
    "2022 Spring_Playoffs": "2022-04-24",
    "2022 Summer_Promotion": "2022-05-08",
    "2022 Summer_Season": "2022-08-21",
    "2022 Summer_Playoffs": "2022-09-04",
    "2023 Spring_Season": "2023-04-10",
    "2023 Spring_Playoffs": "2023-04-23",
    "2023 Summer_Season": "2023-08-06",
    "2023 Summer_Playoffs": "2023-09-09",
    "2024 Spring_Promotion": "2023-11-18",
    "2024 Spring_Season": "2024-03-10",
    "2024 Spring_Playoffs": "2024-04-07",
    "2024 Summer_Season": "2024-08-04",
    "2024 Summer_Playoffs": "2024-08-18"
}

# Define a function to extract the season (Spring, Summer, etc.)
def get_season(tournament):
    if "Spring" in tournament:
        return "Spring"
    elif "Summer" in tournament:
        return "Summer"
    elif "Winter" in tournament:
        return "Winter"
    return ""

# Define a function to extract the event type (Season, Promotion, Playoffs)
def get_event_type(tournament):
    if "Season" in tournament:
        return "Season"
    elif "Promotion" in tournament:
        return "Promotion"
    elif "Playoffs" in tournament:
        return "Playoffs"
    return ""



player_df['Year_Tournamment'] = player_df['Year'].astype(str) + " " + player_df['Tournamment']

# Now, we can map the end date from the dictionary
player_df['Date'] = player_df['Year_Tournamment'].map(end_dates)

# Add the 'Season' column
player_df['Season'] = player_df['Tournamment'].apply(get_season)

# Add the 'Event_Type' column
player_df['Event_Type'] = player_df['Tournamment'].apply(get_event_type)


player_df.drop(columns=['Year_Tournamment'], inplace=True)

player_df['Date'] = pd.to_datetime(player_df['Date'], format='%Y-%m-%d', errors='coerce')


player_df
# Out:
#       Year      Tournamment             Team    Player   G   W   L    WR  \
# 0     2018    Spring_Season   Cherry Esports  Artifact  34  17  17  50.0
# 1     2018    Spring_Season   Cherry Esports     Clear  34  17  17  50.0
# 2     2018    Spring_Season   Cherry Esports      Kidz  34  17  17  50.0
# 3     2018    Spring_Season   Cherry Esports      Potm  34  17  17  50.0
# 4     2018    Spring_Season   Cherry Esports     Boong  13   5   8  38.5
# ...    ...              ...              ...       ...  ..  ..  ..   ...
# 1330  2024  Summer_Playoffs  Vikings Esports       Bie  14   8   6  57.1
# 1331  2024  Summer_Playoffs  Vikings Esports      Gury  14   8   6  57.1
# 1332  2024  Summer_Playoffs  Vikings Esports      Kati  14   8   6  57.1
# 1333  2024  Summer_Playoffs  Vikings Esports    Nanaue  14   8   6  57.1
# 1334  2024  Summer_Playoffs  Vikings Esports    Shogun  14   8   6  57.1
#
#          K     D  ...                     Champs       Role  total_games  \
# 0     4.44  2.74  ...       Azir, Ryze, Vladimir  Mid Laner          134
# 1     3.62  2.29  ...   Caitlyn, Ezreal, Kog'Maw  Bot Laner          134
# 2     0.79  2.97  ...   Braum, Tahm Kench, Janna    Support          134
# 3     2.41  2.85  ...  Kha'Zix, Sejuani, Lee Sin    Jungler          134
# 4     2.38  2.85  ...         Ornn, Gnar, Rumble  Top Laner          134
# ...    ...   ...  ...                        ...        ...          ...
# 1330  1.29  3.00  ...  Rell, Renata Glasc, Senna    Support           25
# 1331  2.00  3.57  ...      Zyra, Maokai, Shyvana    Jungler           25
# 1332  4.71  2.21  ...       Zeri, Corki, Smolder  Mid Laner           25
# 1333  2.93  5.00  ...          Jax, Kennen, Gnar  Top Laner           25
# 1334  3.36  2.57  ...        Ziggs, Ezreal, Ashe  Bot Laner           25
#
#       max_G/M  max_CS/M  max_KDA  max_KPAR       Date  Season  Event_Type
# 0       464.0     10.86     7.80      76.3 2018-03-18  Spring      Season
# 1       464.0     10.86     7.80      76.3 2018-03-18  Spring      Season
# 2       464.0     10.86     7.80      76.3 2018-03-18  Spring      Season
# 3       464.0     10.86     7.80      76.3 2018-03-18  Spring      Season
# 4       464.0     10.86     7.80      76.3 2018-03-18  Spring      Season
# ...       ...       ...      ...       ...        ...     ...         ...
# 1330    491.0     10.89     9.25      78.8 2024-08-18  Summer    Playoffs
# 1331    491.0     10.89     9.25      78.8 2024-08-18  Summer    Playoffs
# 1332    491.0     10.89     9.25      78.8 2024-08-18  Summer    Playoffs
# 1333    491.0     10.89     9.25      78.8 2024-08-18  Summer    Playoffs
# 1334    491.0     10.89     9.25      78.8 2024-08-18  Summer    Playoffs
#
# [1335 rows x 30 columns]

# %%
player_df.to_csv("./data/preprocessed_data/processed_player_stats.csv", index=False, encoding="utf-8")

# %%
player_df = pd.read_csv("./data/preprocessed_data/processed_player_stats.csv", encoding="utf-8")
player_df
# Out:
#       Year      Tournamment             Team    Player   G   W   L    WR  \
# 0     2018    Spring_Season   Cherry Esports  Artifact  34  17  17  50.0
# 1     2018    Spring_Season   Cherry Esports     Clear  34  17  17  50.0
# 2     2018    Spring_Season   Cherry Esports      Kidz  34  17  17  50.0
# 3     2018    Spring_Season   Cherry Esports      Potm  34  17  17  50.0
# 4     2018    Spring_Season   Cherry Esports     Boong  13   5   8  38.5
# ...    ...              ...              ...       ...  ..  ..  ..   ...
# 1330  2024  Summer_Playoffs  Vikings Esports       Bie  14   8   6  57.1
# 1331  2024  Summer_Playoffs  Vikings Esports      Gury  14   8   6  57.1
# 1332  2024  Summer_Playoffs  Vikings Esports      Kati  14   8   6  57.1
# 1333  2024  Summer_Playoffs  Vikings Esports    Nanaue  14   8   6  57.1
# 1334  2024  Summer_Playoffs  Vikings Esports    Shogun  14   8   6  57.1
#
#          K     D  ...  max_G/M  max_CS/M  max_KDA  max_KPAR        Date  \
# 0     4.44  2.74  ...    464.0     10.86     7.80      76.3  2018-03-18
# 1     3.62  2.29  ...    464.0     10.86     7.80      76.3  2018-03-18
# 2     0.79  2.97  ...    464.0     10.86     7.80      76.3  2018-03-18
# 3     2.41  2.85  ...    464.0     10.86     7.80      76.3  2018-03-18
# 4     2.38  2.85  ...    464.0     10.86     7.80      76.3  2018-03-18
# ...    ...   ...  ...      ...       ...      ...       ...         ...
# 1330  1.29  3.00  ...    491.0     10.89     9.25      78.8  2024-08-18
# 1331  2.00  3.57  ...    491.0     10.89     9.25      78.8  2024-08-18
# 1332  4.71  2.21  ...    491.0     10.89     9.25      78.8  2024-08-18
# 1333  2.93  5.00  ...    491.0     10.89     9.25      78.8  2024-08-18
# 1334  3.36  2.57  ...    491.0     10.89     9.25      78.8  2024-08-18
#
#       Season  Event_Type  Champion_1    Champion_2  Champion_3
# 0     Spring      Season        Azir          Ryze    Vladimir
# 1     Spring      Season     Caitlyn        Ezreal     Kog'Maw
# 2     Spring      Season       Braum    Tahm Kench       Janna
# 3     Spring      Season     Kha'Zix       Sejuani     Lee Sin
# 4     Spring      Season        Ornn          Gnar      Rumble
# ...      ...         ...         ...           ...         ...
# 1330  Summer    Playoffs        Rell  Renata Glasc       Senna
# 1331  Summer    Playoffs        Zyra        Maokai     Shyvana
# 1332  Summer    Playoffs        Zeri         Corki     Smolder
# 1333  Summer    Playoffs         Jax        Kennen        Gnar
# 1334  Summer    Playoffs       Ziggs        Ezreal        Ashe
#
# [1335 rows x 32 columns]

# %%
player_df[['Champion_1', 'Champion_2', 'Champion_3']] = player_df['Champs'].str.split(', ', expand=True)

# Xoá cột 'Champs'
player_df.drop(columns=['Champs'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Champs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 player_df[['Champion_1', 'Champion_2', 'Champion_3']] = player_df['Champs'].str.split(', ', expand=True)
#       3 # Xoá cột 'Champs'
#       4 player_df.drop(columns=['Champs'], inplace=True)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Champs'

# %%
player_df[['Champion_1', 'Champion_2', 'Champion_3']] = player_df[['Champion_1', 'Champion_2', 'Champion_3']].fillna("IsNone")

# %%
player_df.describe(include='all')
# Out:
#                Year    Tournamment         Team Player            G  \
# count   1335.000000           1335         1335   1335  1335.000000
# unique          NaN              8           45    325          NaN
# top             NaN  Spring_Season  GAM Esports    Bie          NaN
# freq            NaN            393          146     24          NaN
# mean    2020.887640            NaN          NaN    NaN    17.078652
# std        1.969624            NaN          NaN    NaN    11.722451
# min     2018.000000            NaN          NaN    NaN     1.000000
# 25%     2019.000000            NaN          NaN    NaN     7.000000
# 50%     2021.000000            NaN          NaN    NaN    13.000000
# 75%     2023.000000            NaN          NaN    NaN    29.000000
# max     2024.000000            NaN          NaN    NaN    38.000000
#
#                   W            L           WR            K            D  ...  \
# count   1335.000000  1335.000000  1335.000000  1335.000000  1335.000000  ...
# unique          NaN          NaN          NaN          NaN          NaN  ...
# top             NaN          NaN          NaN          NaN          NaN  ...
# freq            NaN          NaN          NaN          NaN          NaN  ...
# mean       8.539326     8.539326    46.644045     2.917146     3.147858  ...
# std        7.274840     6.518207    23.961682     1.593696     1.016968  ...
# min        0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%        3.000000     3.000000    30.900000     1.670000     2.500000  ...
# 50%        6.000000     6.000000    50.000000     2.890000     3.000000  ...
# 75%       13.000000    13.000000    61.900000     3.955000     3.670000  ...
# max       28.000000    27.000000   100.000000    10.000000    10.000000  ...
#
#             max_G/M     max_CS/M      max_KDA     max_KPAR        Date  \
# count   1335.000000  1335.000000  1335.000000  1335.000000        1335
# unique          NaN          NaN          NaN          NaN          37
# top             NaN          NaN          NaN          NaN  2019-08-11
# freq            NaN          NaN          NaN          NaN          62
# mean     482.803067    10.100412     9.852824    79.068240         NaN
# std       32.647362     0.421619     7.135079     6.427279         NaN
# min      362.388255     8.790000     4.930000    70.900000         NaN
# 25%      463.000000     9.870000     6.100000    74.700000         NaN
# 50%      480.000000    10.020000     7.470000    78.500000         NaN
# 75%      504.000000    10.290000     9.620000    79.700000         NaN
# max      543.000000    11.100000    36.000000   100.000000         NaN
#
#         Season  Event_Type  Champion_1  Champion_2  Champion_3
# count     1335        1335        1335        1335        1335
# unique       3           3         122         138         139
# top     Spring      Season      Kai'Sa      IsNone      IsNone
# freq       657         771          47          51         134
# mean       NaN         NaN         NaN         NaN         NaN
# std        NaN         NaN         NaN         NaN         NaN
# min        NaN         NaN         NaN         NaN         NaN
# 25%        NaN         NaN         NaN         NaN         NaN
# 50%        NaN         NaN         NaN         NaN         NaN
# 75%        NaN         NaN         NaN         NaN         NaN
# max        NaN         NaN         NaN         NaN         NaN
#
# [11 rows x 32 columns]

# %%
player_df.to_csv("./data/preprocessed_data/processed_player_stats.csv", index=False, encoding="utf-8")

# %%
player_df = pd.read_csv("./data/preprocessed_data/processed_player_stats.csv", encoding="utf-8")
player_df.describe(include='all')
# Out:
#                Year    Tournamment         Team Player            G  \
# count   1335.000000           1335         1335   1335  1335.000000
# unique          NaN              8           45    325          NaN
# top             NaN  Spring_Season  GAM Esports    Bie          NaN
# freq            NaN            393          146     24          NaN
# mean    2020.887640            NaN          NaN    NaN    17.078652
# std        1.969624            NaN          NaN    NaN    11.722451
# min     2018.000000            NaN          NaN    NaN     1.000000
# 25%     2019.000000            NaN          NaN    NaN     7.000000
# 50%     2021.000000            NaN          NaN    NaN    13.000000
# 75%     2023.000000            NaN          NaN    NaN    29.000000
# max     2024.000000            NaN          NaN    NaN    38.000000
#
#                   W            L           WR            K            D  ...  \
# count   1335.000000  1335.000000  1335.000000  1335.000000  1335.000000  ...
# unique          NaN          NaN          NaN          NaN          NaN  ...
# top             NaN          NaN          NaN          NaN          NaN  ...
# freq            NaN          NaN          NaN          NaN          NaN  ...
# mean       8.539326     8.539326    46.644045     2.917146     3.147858  ...
# std        7.274840     6.518207    23.961682     1.593696     1.016968  ...
# min        0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%        3.000000     3.000000    30.900000     1.670000     2.500000  ...
# 50%        6.000000     6.000000    50.000000     2.890000     3.000000  ...
# 75%       13.000000    13.000000    61.900000     3.955000     3.670000  ...
# max       28.000000    27.000000   100.000000    10.000000    10.000000  ...
#
#             max_G/M     max_CS/M      max_KDA     max_KPAR        Date  \
# count   1335.000000  1335.000000  1335.000000  1335.000000        1335
# unique          NaN          NaN          NaN          NaN          37
# top             NaN          NaN          NaN          NaN  2019-08-11
# freq            NaN          NaN          NaN          NaN          62
# mean     482.803067    10.100412     9.852824    79.068240         NaN
# std       32.647362     0.421619     7.135079     6.427279         NaN
# min      362.388255     8.790000     4.930000    70.900000         NaN
# 25%      463.000000     9.870000     6.100000    74.700000         NaN
# 50%      480.000000    10.020000     7.470000    78.500000         NaN
# 75%      504.000000    10.290000     9.620000    79.700000         NaN
# max      543.000000    11.100000    36.000000   100.000000         NaN
#
#         Season  Event_Type  Champion_1  Champion_2  Champion_3
# count     1335        1335        1335        1335        1335
# unique       3           3         122         138         139
# top     Spring      Season      Kai'Sa      IsNone      IsNone
# freq       657         771          47          51         134
# mean       NaN         NaN         NaN         NaN         NaN
# std        NaN         NaN         NaN         NaN         NaN
# min        NaN         NaN         NaN         NaN         NaN
# 25%        NaN         NaN         NaN         NaN         NaN
# 50%        NaN         NaN         NaN         NaN         NaN
# 75%        NaN         NaN         NaN         NaN         NaN
# max        NaN         NaN         NaN         NaN         NaN
#
# [11 rows x 32 columns]

# %%
player_df = pd.read_csv("./data/preprocessed_data/processed_player_stats.csv", encoding="utf-8")
player_df.describe(include='all')
# Out:
#                Year    Tournamment         Team Player            G  \
# count   1335.000000           1335         1335   1335  1335.000000
# unique          NaN              8           45    325          NaN
# top             NaN  Spring_Season  GAM Esports    Bie          NaN
# freq            NaN            393          146     24          NaN
# mean    2020.887640            NaN          NaN    NaN    17.078652
# std        1.969624            NaN          NaN    NaN    11.722451
# min     2018.000000            NaN          NaN    NaN     1.000000
# 25%     2019.000000            NaN          NaN    NaN     7.000000
# 50%     2021.000000            NaN          NaN    NaN    13.000000
# 75%     2023.000000            NaN          NaN    NaN    29.000000
# max     2024.000000            NaN          NaN    NaN    38.000000
#
#                   W            L           WR            K            D  ...  \
# count   1335.000000  1335.000000  1335.000000  1335.000000  1335.000000  ...
# unique          NaN          NaN          NaN          NaN          NaN  ...
# top             NaN          NaN          NaN          NaN          NaN  ...
# freq            NaN          NaN          NaN          NaN          NaN  ...
# mean       8.539326     8.539326    46.644045     2.917146     3.147858  ...
# std        7.274840     6.518207    23.961682     1.593696     1.016968  ...
# min        0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%        3.000000     3.000000    30.900000     1.670000     2.500000  ...
# 50%        6.000000     6.000000    50.000000     2.890000     3.000000  ...
# 75%       13.000000    13.000000    61.900000     3.955000     3.670000  ...
# max       28.000000    27.000000   100.000000    10.000000    10.000000  ...
#
#             max_G/M     max_CS/M      max_KDA     max_KPAR        Date  \
# count   1335.000000  1335.000000  1335.000000  1335.000000        1335
# unique          NaN          NaN          NaN          NaN          37
# top             NaN          NaN          NaN          NaN  2019-08-11
# freq            NaN          NaN          NaN          NaN          62
# mean     482.803067    10.100412     9.852824    79.068240         NaN
# std       32.647362     0.421619     7.135079     6.427279         NaN
# min      362.388255     8.790000     4.930000    70.900000         NaN
# 25%      463.000000     9.870000     6.100000    74.700000         NaN
# 50%      480.000000    10.020000     7.470000    78.500000         NaN
# 75%      504.000000    10.290000     9.620000    79.700000         NaN
# max      543.000000    11.100000    36.000000   100.000000         NaN
#
#         Season  Event_Type  Champion_1  Champion_2  Champion_3
# count     1335        1335        1335        1335        1335
# unique       3           3         122         138         139
# top     Spring      Season      Kai'Sa      IsNone      IsNone
# freq       657         771          47          51         134
# mean       NaN         NaN         NaN         NaN         NaN
# std        NaN         NaN         NaN         NaN         NaN
# min        NaN         NaN         NaN         NaN         NaN
# 25%        NaN         NaN         NaN         NaN         NaN
# 50%        NaN         NaN         NaN         NaN         NaN
# 75%        NaN         NaN         NaN         NaN         NaN
# max        NaN         NaN         NaN         NaN         NaN
#
# [11 rows x 32 columns]
